# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

#working with purchase_data.csv for heroes of pymoli
#basically this is making a buttload of tables, grouping,binning,sorting
#step 1 is load purchase_data


game_data=pd.read_csv(r"C:\Users\The Doctor\Anaconda3\envs\PythonData\purchase_data.csv")
game_data
# Out:
#      Purchase ID               SN  Age                 Gender  Item ID  \
# 0              0          Lisim78   20                   Male      108
# 1              1      Lisovynya38   40                   Male      143
# 2              2       Ithergue48   24                   Male       92
# 3              3    Chamassasya86   24                   Male      100
# 4              4        Iskosia90   23                   Male      131
# 5              5          Yalae81   22                   Male       81
# 6              6        Itheria73   36                   Male      169
# 7              7      Iskjaskst81   20                   Male      162
# 8              8        Undjask33   22                   Male       21
# 9              9      Chanosian48   35  Other / Non-Disclosed      136
# 10            10        Inguron55   23                   Male       95
# 11            11     Haisrisuir60   23                   Male      162
# ...

# %%
#this is total players, -1 zaps column name
Total = game_data['Gender'].count()
print (Total-1)
# Out:
# 779

# %%
#this is total revenue
total_rev=game_data['Price'].sum()
total_rev
# Out:
# 2379.77

# %%
#this is number of purchases, is just total players
total_purch=(Total-1)
total_purch
# Out:
# 779

# %%
average = game_data['Price'].mean()
average
# Out:
# 3.050987179487176

# %%
#this is total of unique items
unique = game_data['Item Name'].unique()
unique
# Out:
# array(['Extraction, Quickblade Of Trembling Hands', 'Frenzied Scimitar',
#        'Final Critic', 'Blindscythe', 'Fury', 'Dreamkiss',
#        'Interrogator, Blood Blade of the Queen', 'Abyssal Shard',
#        'Souleater', 'Ghastly Adamantite Protector',
#        'Singed Onyx Warscythe', 'Renewed Skeletal Katana',
#        "Bloodlord's Fetish", 'Bone Crushing Silver Skewer',
#        'Deadline, Voice Of Subtlety', 'Second Chance', 'Devine',
#        'Nirvana', 'Blazefury, Protector of Delusions',
#        'Despair, Favor of Due Diligence',
#        'Sun Strike, Jaws of Twisted Visions', 'Warped Fetish',
#        'Severance', 'Persuasion',
#        'Oathbreaker, Last Hope of the Breaking Storm', 'Demise',
#        'Blood-Forged Skeletal Spine',
#        'Stormbringer, Dark Blade of Ending Misery',
#        'Shadow Strike, Glory of Ending Hope', 'Striker',
#        'Wolf, Promise of the Moonwalker', "Faith's Scimitar",
# ...

# %%
count = game_data["Item Name"].value_counts()
count
# Out:
# Final Critic                                    13
# Oathbreaker, Last Hope of the Breaking Storm    12
# Nirvana                                          9
# Fiery Glass Crusader                             9
# Persuasion                                       9
# Extraction, Quickblade Of Trembling Hands        9
# Brutality Ivory Warmace                          8
# Shadow Strike, Glory of Ending Hope              8
# Wolf                                             8
# Retribution Axe                                  8
# Lightning, Etcher of the King                    8
# Winter's Bite                                    8
# Singed Scalpel                                   8
# Pursuit, Cudgel of Necromancy                    8
# Glimmer, Ender of the Moon                       7
# Malificent Bag                                   7
# Heartstriker, Legacy of the Light                7
# Thorn, Satchel of Dark Souls                     7
# ...

# %%
Total_uni = count.count()
print (Total_uni)
# Out:
# 179

# %%
# Creating a summary DataFrame using above values, irritating output bd by m f
pa_df = pd.DataFrame({"Unique Items": [Total_uni],
                            "Average Price": [average],
                            "Number Purchases": [total_purch],
                             "Total Revenue": [total_rev]})
pa_df
# Out:
#    Unique Items  Average Price  Number Purchases  Total Revenue
# 0           179       3.050987               779        2379.77

# %%
#dropping index
pa_df.style.hide_index()
# Out:
# <style  type="text/css" >
# </style><table id="T_a01049d8_d4ed_11e9_9c45_b46921929ff9" ><thead>    <tr>        <th class="col_heading level0 col0" >Unique Items</th>        <th class="col_heading level0 col1" >Average Price</th>        <th class="col_heading level0 col2" >Number Purchases</th>        <th class="col_heading level0 col3" >Total Revenue</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_a01049d8_d4ed_11e9_9c45_b46921929ff9row0_col0" class="data row0 col0" >179</td>
#                         <td id="T_a01049d8_d4ed_11e9_9c45_b46921929ff9row0_col1" class="data row0 col1" >3.05099</td>
#                         <td id="T_a01049d8_d4ed_11e9_9c45_b46921929ff9row0_col2" class="data row0 col2" >779</td>
#                         <td id="T_a01049d8_d4ed_11e9_9c45_b46921929ff9row0_col3" class="data row0 col3" >2379.77</td>
#             </tr>
#     </tbody></table>

# %%
#gender_count
gender_count=game_data.groupby('Gender').size()
print(gender_count)
# Out:
# Gender
# Female                   113
# Male                     652
# Other / Non-Disclosed     15
# dtype: int64

# %%
#do a percentages
Genders=(game_data['Gender'].value_counts(normalize=True) * 100)
print(Genders)
# Out:
# Male                     83.589744
# Female                   14.487179
# Other / Non-Disclosed     1.923077
# Name: Gender, dtype: float64

# %%
# Using GroupBy in order to separate the data into fields according to "sex" values
grouped_sex_df = game_data.groupby(['Gender'])
# The object returned is a "GroupBy" object and cannot be viewed normally...
print(grouped_sex_df)

# %%
# In order to be visualized, a data function must be used...
grouped_sex_df.count().head(10)
# Out:
#                        Purchase ID   SN  Age  Item ID  Item Name  Price
# Gender
# Female                         113  113  113      113        113    113
# Male                           652  652  652      652        652    652
# Other / Non-Disclosed           15   15   15       15         15     15

# %%
# Count how many sightings have occured within each sex
sex_counts = game_data["Gender"].value_counts()
sex_counts.head()
# Out:
# Male                     652
# Female                   113
# Other / Non-Disclosed     15
# Name: Gender, dtype: int64

# %%
# Creating a new DataFrame using both duration and count
sex_summary_table = pd.DataFrame({"Number of Sex": sex_counts})
sex_summary_table.head()
# Out:
#                        Number of Sex
# Male                             652
# Female                           113
# Other / Non-Disclosed             15

# %%
#do a percentages
Genders=(game_data['Gender'].value_counts(normalize=True) * 100)
Genders.head()
# Out:
# Male                     83.589744
# Female                   14.487179
# Other / Non-Disclosed     1.923077
# Name: Gender, dtype: float64

# %%
# Creating a new DataFrame using both duration and count
sex_summary_table2 = pd.DataFrame({"Number of Sex": sex_counts,
                                  "Perc sex": Genders})
sex_summary_table.head()
# Out:
#                        Number of Sex
# Male                             652
# Female                           113
# Other / Non-Disclosed             15

# %%
# Creating a new DataFrame using both duration and count
sex_summary_table2 = pd.DataFrame({"Number of Sex": sex_counts,
                                     "Perc sex": Genders})
sex_summary_table2.head()
# Out:
#                        Number of Sex   Perc sex
# Male                             652  83.589744
# Female                           113  14.487179
# Other / Non-Disclosed             15   1.923077

# %%
sex_rev = grouped_sex_df["Price"].sum()
sex_rev.head()
# Out:
# Gender
# Female                    361.94
# Male                     1967.64
# Other / Non-Disclosed      50.19
# Name: Price, dtype: float64

# %%
#avg by sex
average_sex = grouped_sex_df['Price'].mean()
average_sex.head()
# Out:
# Gender
# Female                   3.203009
# Male                     3.017853
# Other / Non-Disclosed    3.346000
# Name: Price, dtype: float64

# %%
#purch count is just sex count
total_purch_sex=game_data["Gender"].value_counts()
total_purch_sex
# Out:
# Male                     652
# Female                   113
# Other / Non-Disclosed     15
# Name: Gender, dtype: int64

# %%
sex_summary_table3.index.name='Gender'
sex_summary_table3.head(5)

# %%
# Creating a new DataFrame using above crap
sex_summary_table3 = pd.DataFrame({"Number of Sex purchases": total_purch_sex,
                                     "Avg ": average_sex,
                                        "Revenue": sex_rev})
sex_summary_table3.head()
# Out:
#                        Number of Sex purchases      Avg   Revenue
# Female                                     113  3.203009   361.94
# Male                                       652  3.017853  1967.64
# Other / Non-Disclosed                       15  3.346000    50.19

# %%
sex_summary_table3.index.name='Gender'
sex_summary_table3.head(5)
# Out:
#                        Number of Sex purchases      Avg   Revenue
# Gender
# Female                                     113  3.203009   361.94
# Male                                       652  3.017853  1967.64
# Other / Non-Disclosed                       15  3.346000    50.19

# %%
bins = [0, 14, 19, 24, 29, 34, 39, 100]

# Create the names for the four bins
group_names = ["0-14", "15-19", "20-24", "25-29", "30-34", "35-39", "older"]

#df["Test Score Summary"] = pd.cut(df["Test Score"], bins, labels=group_names)
game_data["Age"] =pd.cut(game_data["Age"], bins, labels=group_names)
game_data
# Out:
#      Purchase ID               SN    Age                 Gender  Item ID  \
# 0              0          Lisim78  20-24                   Male      108
# 1              1      Lisovynya38  older                   Male      143
# 2              2       Ithergue48  20-24                   Male       92
# 3              3    Chamassasya86  20-24                   Male      100
# 4              4        Iskosia90  20-24                   Male      131
# 5              5          Yalae81  20-24                   Male       81
# 6              6        Itheria73  35-39                   Male      169
# 7              7      Iskjaskst81  20-24                   Male      162
# 8              8        Undjask33  20-24                   Male       21
# 9              9      Chanosian48  35-39  Other / Non-Disclosed      136
# 10            10        Inguron55  20-24                   Male       95
# 11            11     Haisrisuir60  20-24                   Male      162
# ...

# %%
# Count how many sightings have occured within each sex
age_counts = game_data["Age"].value_counts()
age_counts.head()
# Out:
# 20-24    365
# 15-19    136
# 25-29    101
# 30-34     73
# 0-14      51
# Name: Age, dtype: int64

# %%
#get age %
age_perc=(game_data['Age'].value_counts(normalize=True) * 100)
age_perc.head()
# Out:
# 20-24    46.794872
# 15-19    17.435897
# 25-29    12.948718
# 30-34     9.358974
# 0-14      6.538462
# Name: Age, dtype: float64

# %%
age_demo = pd.DataFrame({"Age": group_names,
                            "Total": age_counts,
                                     "% ": age_perc})
                                        
age_demo.head()
# Out:
#          Age  Total         %
# 20-24   0-14    365  46.794872
# 15-19  15-19    136  17.435897
# 25-29  20-24    101  12.948718
# 30-34  25-29     73   9.358974
# 0-14   30-34     51   6.538462

# %%
age_demo.style.hide_index()
# Out:
# <style  type="text/css" >
# </style><table id="T_d7f5cb98_d4d1_11e9_942d_b46921929ff9" ><thead>    <tr>        <th class="col_heading level0 col0" >Age</th>        <th class="col_heading level0 col1" >Total</th>        <th class="col_heading level0 col2" >% </th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_d7f5cb98_d4d1_11e9_942d_b46921929ff9row0_col0" class="data row0 col0" >0-14</td>
#                         <td id="T_d7f5cb98_d4d1_11e9_942d_b46921929ff9row0_col1" class="data row0 col1" >365</td>
#                         <td id="T_d7f5cb98_d4d1_11e9_942d_b46921929ff9row0_col2" class="data row0 col2" >46.7949</td>
#             </tr>
#             <tr>
#                                 <td id="T_d7f5cb98_d4d1_11e9_942d_b46921929ff9row1_col0" class="data row1 col0" >15-19</td>
#                         <td id="T_d7f5cb98_d4d1_11e9_942d_b46921929ff9row1_col1" class="data row1 col1" >136</td>
# ...

# %%
SN_groups = game_data.groupby(['SN'])
SN_groups.head()
# Out:
#      Purchase ID               SN    Age                 Gender  Item ID  \
# 0              0          Lisim78  20-24                   Male      108
# 1              1      Lisovynya38  older                   Male      143
# 2              2       Ithergue48  20-24                   Male       92
# 3              3    Chamassasya86  20-24                   Male      100
# 4              4        Iskosia90  20-24                   Male      131
# 5              5          Yalae81  20-24                   Male       81
# 6              6        Itheria73  35-39                   Male      169
# 7              7      Iskjaskst81  20-24                   Male      162
# 8              8        Undjask33  20-24                   Male       21
# 9              9      Chanosian48  35-39  Other / Non-Disclosed      136
# 10            10        Inguron55  20-24                   Male       95
# 11            11     Haisrisuir60  20-24                   Male      162
# ...

# %%
# Create a new variable that holds the sum of our groups
sum_it_up = SN_groups.sum()
sum_it_up.head(12)
# Out:
#               Purchase ID  Item ID  Price
# SN
# Adairialis76          467      123   2.28
# Adastirin33           142      175   4.48
# Aeda94                388      128   4.91
# Aela59                 28      119   4.32
# Aelaria33             630      171   1.79
# Aelastirin39          984      134   7.29
# Aelidru27             705      183   1.09
# Aelin32               723      326   8.98
# Aelly27               471      130   6.79
# Aellynun67            286      153   3.74
# Aellyria80            746      159   3.08
# Aelollo59             634      175   5.63

# %%
  #get count by person by person
SN_purchase=game_data['SN'].value_counts()
SN_purchase.head()
# Out:
# Lisosia93       5
# Idastidru52     4
# Iral74          4
# Sondastsda82    3
# Yathecal82      3
# Name: SN, dtype: int64

# %%
# Sorting the DataFrame based on "price" column
# Will sort from lowest to highest if no other parameter is passed
sum_it_up_sort = sum_it_up.sort_values("Price")
sum_it_up_sort.head(5)
# Out:
#             Purchase ID  Item ID  Price
# SN
# Alo38                63      125   1.00
# Aidai61             282      155   1.01
# Chanirra79          586      155   1.01
# Isurria36           528       19   1.02
# Irilis75            582       19   1.02

# %%
sum_it_up_sort = sum_it_up.sort_values("Price", ascending=False)
sum_it_up_sort.head(5)
# Out:
#              Purchase ID  Item ID  Price
# SN
# Lisosia93           1630      451  18.96
# Idastidru52         1999      527  15.45
# Chamjask73          1306      339  13.83
# Iral74              2285      518  13.62
# Iskadarya95          713      321  13.10

# %%
 #avg by SN
average_sn_price = sum_it_up_sort['Price'].mean()
average_sn_price.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-126-f6922bcb7dc9> in <module>
#       1 #avg by SN
#       2 average_sn_price = sum_it_up_sort['Price'].mean()
# ----> 3 average_sn_price.head()
#
# AttributeError: 'float' object has no attribute 'head'

# %%
sum_it_up_mean = SN_groups.mean()
sum_it_up_mean.head(12)
# Out:
#               Purchase ID   Age     Item ID     Price
# SN
# Adairialis76        467.0  16.0  123.000000  2.280000
# Adastirin33         142.0  35.0  175.000000  4.480000
# Aeda94              388.0  17.0  128.000000  4.910000
# Aela59               28.0  21.0  119.000000  4.320000
# Aelaria33           630.0  23.0  171.000000  1.790000
# Aelastirin39        492.0  23.0   67.000000  3.645000
# Aelidru27           705.0  22.0  183.000000  1.090000
# Aelin32             241.0  20.0  108.666667  2.993333
# Aelly27             235.5  24.0   65.000000  3.395000
# Aellynun67          286.0  25.0  153.000000  3.740000
# Aellyria80          746.0  23.0  159.000000  3.080000
# Aelollo59           317.0  33.0   87.500000  2.815000

# %%
sum_it_up.head()
# Out:
#               Purchase ID  Item ID  Price
# SN
# Adairialis76          467      123   2.28
# Adastirin33           142      175   4.48
# Aeda94                388      128   4.91
# Aela59                 28      119   4.32
# Aelaria33             630      171   1.79

# %%
# Sorting the DataFrame based on "price" column
# Will sort from lowest to highest if no other parameter is passed
sum_it_up_sort = sum_it_up.sort_values('Price', ascending=False)
sum_it_up_sort.head(5)
# Out:
#              Purchase ID  Item ID  Price
# SN
# Lisosia93           1630      451  18.96
# Idastidru52         1999      527  15.45
# Chamjask73          1306      339  13.83
# Iral74              2285      518  13.62
# Iskadarya95          713      321  13.10

# %%
# Create a new variable that holds the sum of our groups
sum_it_up2 = SN_groups['Price'].sum()
sum_it_up2.head(12)
# Out:
# SN
# Adairialis76    2.28
# Adastirin33     4.48
# Aeda94          4.91
# Aela59          4.32
# Aelaria33       1.79
# Aelastirin39    7.29
# Aelidru27       1.09
# Aelin32         8.98
# Aelly27         6.79
# Aellynun67      3.74
# Aellyria80      3.08
# Aelollo59       5.63
# Name: Price, dtype: float64

# %%
#total
sn_stuff = pd.DataFrame({"Total $": sum_it_up2,
                            "Count": SN_purchase})
sn_stuff.head()
# Out:
#               Total $  Count
# Adairialis76     2.28      1
# Adastirin33      4.48      1
# Aeda94           4.91      1
# Aela59           4.32      1
# Aelaria33        1.79      1

# %%
# Sorting the DataFrame based on "price" column
# Will sort from lowest to highest if no other parameter is passed
sn_sort = sn_stuff.sort_values('Total $', ascending=False)
sn_sort.head(5)
# Out:
#              Total $  Count
# Lisosia93      18.96      5
# Idastidru52    15.45      4
# Chamjask73     13.83      3
# Iral74         13.62      4
# Iskadarya95    13.10      3

# %%
SN_avg = SN_groups['Price'].mean()
SN_avg
# Out:
# SN
# Adairialis76       2.280000
# Adastirin33        4.480000
# Aeda94             4.910000
# Aela59             4.320000
# Aelaria33          1.790000
# Aelastirin39       3.645000
# Aelidru27          1.090000
# Aelin32            2.993333
# Aelly27            3.395000
# Aellynun67         3.740000
# Aellyria80         3.080000
# Aelollo59          2.815000
# Aenarap34          2.960000
# Aeral43            4.400000
# Aeral68            4.000000
# Aeral97            4.800000
# Aeralria27         4.090000
# Aeralstical35      2.960000
# Aeri84             1.610000
# Aerillorin70       3.330000
# Aerithllora36      4.320000
# Aerithnucal56      4.400000
# Aerithnuphos61     4.910000
# Aerithriaphos45    1.560000
# Aerithriaphos46    2.180000
# Aesri53            1.760000
# Aesty53            1.955000
# Aestysu37          2.690000
# Aesur96            2.210000
# Aesurstilis64      1.030000
#                      ...
# Undosia27          3.770000
# Undosian34         4.150000
# ...

# %%
sn_stuff = pd.DataFrame({"Total $": sum_it_up2,
                            "Count": SN_purchase,
                                "AVG": SN_avg})
sn_stuff.head()
# Out:
#               Total $  Count   AVG
# Adairialis76     2.28      1  2.28
# Adastirin33      4.48      1  4.48
# Aeda94           4.91      1  4.91
# Aela59           4.32      1  4.32
# Aelaria33        1.79      1  1.79

# %%
sn_sort = sn_stuff.sort_values('Total $', ascending=False)
sn_sort.head(5)
# Out:
#              Total $  Count       AVG
# Lisosia93      18.96      5  3.792000
# Idastidru52    15.45      4  3.862500
# Chamjask73     13.83      3  4.610000
# Iral74         13.62      4  3.405000
# Iskadarya95    13.10      3  4.366667

# %%
sn_sort.index.name='SN'
sn_sort.head(5)
# Out:
#              Total $  Count       AVG
# SN
# Lisosia93      18.96      5  3.792000
# Idastidru52    15.45      4  3.862500
# Chamjask73     13.83      3  4.610000
# Iral74         13.62      4  3.405000
# Iskadarya95    13.10      3  4.366667

# %%
# Split up our data into groups based upon 'Item ID' 
Item_groups = game_data.groupby(['Item ID'])
Item_groups.head()
# Out:
#      Purchase ID               SN    Age                 Gender  Item ID  \
# 0              0          Lisim78  20-24                   Male      108
# 1              1      Lisovynya38  older                   Male      143
# 2              2       Ithergue48  20-24                   Male       92
# 3              3    Chamassasya86  20-24                   Male      100
# 4              4        Iskosia90  20-24                   Male      131
# 5              5          Yalae81  20-24                   Male       81
# 6              6        Itheria73  35-39                   Male      169
# 7              7      Iskjaskst81  20-24                   Male      162
# 8              8        Undjask33  20-24                   Male       21
# 9              9      Chanosian48  35-39  Other / Non-Disclosed      136
# 10            10        Inguron55  20-24                   Male       95
# 11            11     Haisrisuir60  20-24                   Male      162
# ...

# %%
Item_groups = game_data.groupby(['Item ID'])
Item_groups.head()
# Out:
#      Purchase ID               SN    Age                 Gender  Item ID  \
# 0              0          Lisim78  20-24                   Male      108
# 1              1      Lisovynya38  older                   Male      143
# 2              2       Ithergue48  20-24                   Male       92
# 3              3    Chamassasya86  20-24                   Male      100
# 4              4        Iskosia90  20-24                   Male      131
# 5              5          Yalae81  20-24                   Male       81
# 6              6        Itheria73  35-39                   Male      169
# 7              7      Iskjaskst81  20-24                   Male      162
# 8              8        Undjask33  20-24                   Male       21
# 9              9      Chanosian48  35-39  Other / Non-Disclosed      136
# 10            10        Inguron55  20-24                   Male       95
# 11            11     Haisrisuir60  20-24                   Male      162
# ...

# %%
# Count how many sightings have occured within each item
item_counts = game_data['Item ID'].value_counts()
item_counts.head()
# Out:
# 178    12
# 82      9
# 108     9
# 145     9
# 92      8
# Name: Item ID, dtype: int64

# %%
# Split up our data into groups based upon 'Item ID' 
Item_groups = game_data.groupby(['Item ID'])
Item_groups2.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-139-c523dace2a2a> in <module>
#       1 # Split up our data into groups based upon 'Item ID'
#       2 Item_groups = game_data.groupby(['Item ID'])
# ----> 3 Item_groups2.head()
#
# NameError: name 'Item_groups2' is not defined

# %%
#item price
Item_price=Item_groups['Price']
Item_price.head()
# Out:
# 0      3.53
# 1      1.56
# 2      4.88
# 3      3.27
# 4      1.44
# 5      3.61
# 6      2.18
# 7      2.67
# 8      1.10
# 9      3.58
# 10     4.74
# 11     2.67
# 12     4.18
# 13     1.70
# 14     4.86
# 15     2.89
# 16     2.52
# 17     1.76
# 18     4.90
# 19     4.64
# 20     4.60
# 21     1.48
# 22     3.81
# 23     3.40
# 24     3.19
# 25     4.23
# 26     1.61
# 27     3.09
# 28     4.32
# 29     3.16
#        ...
# 731    1.02
# 732    2.50
# 733    4.40
# 734    4.86
# 736    4.14
# 737    1.75
# 738    1.60
# 739    3.87
# 740    3.92
# 742    4.08
# 744    3.49
# 747    3.10
# 748    2.27
# 750    3.61
# 751    3.36
# 752    2.60
# 754    4.05
# 755    3.15
# 756    2.05
# 757    4.60
# 758    4.03
# 760    2.38
# 761    1.70
# 764    4.07
# 765    2.07
# 766    4.14
# 774    4.19
# 777    3.46
# 778    4.19
# 779    4.60
# Name: Price, Length: 697, dtype: float64

# %%
Item_sum=Item_groups['Price'].sum()
Item_sum.head()
# Out:
# Item ID
# 0     5.12
# 1     9.78
# 2    14.88
# 3    14.94
# 4     8.50
# Name: Price, dtype: float64

# %%
#got it, sort it, display it
Item_stuff = pd.DataFrame({"Count": item_counts})
Item_stuff.head()
# Out:
#      Count
# 178     12
# 82       9
# 108      9
# 145      9
# 92       8

# %%
item_sort = Item_stuff.sort_values('Count', ascending=False)
item_sort.head(5)
# Out:
#      Count
# 178     12
# 108      9
# 145      9
# 82       9
# 72       8

# %%
Item_Cost=(Item_sum/item_counts)
Item_Cost.head()
# Out:
# 0    1.28
# 1    3.26
# 2    2.48
# 3    2.49
# 4    1.70
# dtype: float64

# %%
Item_name=game_data['Item Name']
Item_name.head()
# Out:
# 0    Extraction, Quickblade Of Trembling Hands
# 1                            Frenzied Scimitar
# 2                                 Final Critic
# 3                                  Blindscythe
# 4                                         Fury
# Name: Item Name, dtype: object

# %%
Item_ID=game_data['Item ID']
Item_ID.head()
# Out:
# 0    108
# 1    143
# 2     92
# 3    100
# 4    131
# Name: Item ID, dtype: int64

# %%
#got it, sort it, display it
Item_junk = pd.DataFrame({"Item Name": Item_name,
                            "Total $": Item_sum,
                             "Count": item_counts,
                                 "Price": Item_Cost})
                            
                                
Item_junk.head()
# Out:
#                                    Item Name  Total $  Count  Price
# 0  Extraction, Quickblade Of Trembling Hands     5.12    4.0   1.28
# 1                          Frenzied Scimitar     9.78    3.0   3.26
# 2                               Final Critic    14.88    6.0   2.48
# 3                                Blindscythe    14.94    6.0   2.49
# 4                                       Fury     8.50    5.0   1.70

# %%
#got it, sort it, display it this is what I want
Item_junk = pd.DataFrame({"Item ID": Item_ID,
                            "Item Name": Item_name,
                            "Total $": Item_sum,
                             "Count": item_counts,
                                 "Price": Item_Cost})
Item_junk.head()
# Out:
#    Item ID                                  Item Name  Total $  Count  Price
# 0      108  Extraction, Quickblade Of Trembling Hands     5.12    4.0   1.28
# 1      143                          Frenzied Scimitar     9.78    3.0   3.26
# 2       92                               Final Critic    14.88    6.0   2.48
# 3      100                                Blindscythe    14.94    6.0   2.49
# 4      131                                       Fury     8.50    5.0   1.70

# %%
#and sort
item_sort2 = Item_junk.sort_values('Count', ascending=False)
item_sort2.head(5)
# Out:
#      Item ID                          Item Name  Total $  Count  Price
# 178       57    Despair, Favor of Due Diligence    50.76   12.0   4.23
# 145       46            Hopeless Ebon Dualblade    41.22    9.0   4.58
# 108       85                     Malificent Bag    31.77    9.0   3.53
# 82       160                         Azurewrath    44.10    9.0   4.90
# 19        89  Blazefury, Protector of Delusions     8.16    8.0   1.02

# %%
item_sort2.style.hide_index()
# Out:
# <style  type="text/css" >
# </style><table id="T_289dc65e_d4cf_11e9_8f9e_b46921929ff9" ><thead>    <tr>        <th class="col_heading level0 col0" >Item ID</th>        <th class="col_heading level0 col1" >Item Name</th>        <th class="col_heading level0 col2" >Total $</th>        <th class="col_heading level0 col3" >Count</th>        <th class="col_heading level0 col4" >Price</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_289dc65e_d4cf_11e9_8f9e_b46921929ff9row0_col0" class="data row0 col0" >57</td>
#                         <td id="T_289dc65e_d4cf_11e9_8f9e_b46921929ff9row0_col1" class="data row0 col1" >Despair, Favor of Due Diligence</td>
#                         <td id="T_289dc65e_d4cf_11e9_8f9e_b46921929ff9row0_col2" class="data row0 col2" >50.76</td>
#                         <td id="T_289dc65e_d4cf_11e9_8f9e_b46921929ff9row0_col3" class="data row0 col3" >12</td>
# ...

# %%
item_sort3=item_sort2.head(5)
item_sort3
# Out:
#      Item ID                          Item Name  Total $  Count  Price
# 178       57    Despair, Favor of Due Diligence    50.76   12.0   4.23
# 145       46            Hopeless Ebon Dualblade    41.22    9.0   4.58
# 108       85                     Malificent Bag    31.77    9.0   3.53
# 82       160                         Azurewrath    44.10    9.0   4.90
# 19        89  Blazefury, Protector of Delusions     8.16    8.0   1.02

# %%
item_sort3.style.hide_index()
# Out:
# <style  type="text/css" >
# </style><table id="T_3d89ca2e_d4d2_11e9_a714_b46921929ff9" ><thead>    <tr>        <th class="col_heading level0 col0" >Item ID</th>        <th class="col_heading level0 col1" >Item Name</th>        <th class="col_heading level0 col2" >Total $</th>        <th class="col_heading level0 col3" >Count</th>        <th class="col_heading level0 col4" >Price</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_3d89ca2e_d4d2_11e9_a714_b46921929ff9row0_col0" class="data row0 col0" >57</td>
#                         <td id="T_3d89ca2e_d4d2_11e9_a714_b46921929ff9row0_col1" class="data row0 col1" >Despair, Favor of Due Diligence</td>
#                         <td id="T_3d89ca2e_d4d2_11e9_a714_b46921929ff9row0_col2" class="data row0 col2" >50.76</td>
#                         <td id="T_3d89ca2e_d4d2_11e9_a714_b46921929ff9row0_col3" class="data row0 col3" >12</td>
# ...

# %%
#* Identify the 5 most profitable items by total purchase value, then list (in a table):
 # * Item ID
 # * Item Name
 # * Purchase Count
 # * Item Price
 # * Total Purchase Value

 #this is just a rearranging of the previous table

# %%
item_sort4 = Item_junk.sort_values('Total $', ascending=False)
item_sort4.head(5)
# Out:
#      Item ID                             Item Name  Total $  Count  Price
# 178       57       Despair, Favor of Due Diligence    50.76   12.0   4.23
# 82       160                            Azurewrath    44.10    9.0   4.90
# 145       46               Hopeless Ebon Dualblade    41.22    9.0   4.58
# 92        39  Betrayal, Whisper of Grieving Widows    39.04    8.0   4.88
# 103        7          Thorn, Satchel of Dark Souls    34.80    8.0   4.35

# %%
item_sort5=item_sort4.head(5)
item_sort5
# Out:
#      Item ID                             Item Name  Total $  Count  Price
# 178       57       Despair, Favor of Due Diligence    50.76   12.0   4.23
# 82       160                            Azurewrath    44.10    9.0   4.90
# 145       46               Hopeless Ebon Dualblade    41.22    9.0   4.58
# 92        39  Betrayal, Whisper of Grieving Widows    39.04    8.0   4.88
# 103        7          Thorn, Satchel of Dark Souls    34.80    8.0   4.35

# %%
item_sort5.style.hide_index()
# Out:
# <style  type="text/css" >
# </style><table id="T_ae0880f6_d4ee_11e9_a086_b46921929ff9" ><thead>    <tr>        <th class="col_heading level0 col0" >Item ID</th>        <th class="col_heading level0 col1" >Item Name</th>        <th class="col_heading level0 col2" >Total $</th>        <th class="col_heading level0 col3" >Count</th>        <th class="col_heading level0 col4" >Price</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_ae0880f6_d4ee_11e9_a086_b46921929ff9row0_col0" class="data row0 col0" >57</td>
#                         <td id="T_ae0880f6_d4ee_11e9_a086_b46921929ff9row0_col1" class="data row0 col1" >Despair, Favor of Due Diligence</td>
#                         <td id="T_ae0880f6_d4ee_11e9_a086_b46921929ff9row0_col2" class="data row0 col2" >50.76</td>
#                         <td id="T_ae0880f6_d4ee_11e9_a086_b46921929ff9row0_col3" class="data row0 col3" >12</td>
# ...
